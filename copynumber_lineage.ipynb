# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score

from sklearn.linear_model import LogisticRegression

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

import matplotlib.pyplot as plt

# %%
gene_effect_df = pd.read_csv("GeneCN.csv").rename(columns = {'Unnamed: 0': 'ModelID'})
model_df = pd.read_csv("Model.csv")

merged_df = pd.merge(gene_effect_df, model_df[['ModelID','CellLineName','OncotreeLineage']], on='ModelID', how='inner')

new_cols = gene_effect_df.columns.tolist()
new_cols.insert(1, "OncotreeLineage")
# new_cols.insert(2, "CellLineName")

gene_df = merged_df[new_cols]

# %%
categorical_mapping = {item: idx for idx, item in enumerate(list(gene_df['OncotreeLineage'].unique()))}
gene_df['Lineage as Number'] = gene_df['OncotreeLineage'].map(categorical_mapping)

gene_df = gene_df.fillna(0)

gene_df = gene_df.set_index('ModelID')

# gene_df.head()

# %%
X = gene_df.drop(columns = ['Lineage as Number', 'OncotreeLineage'])
y = gene_df['Lineage as Number']

# %%
X_train_log, X_test_log, y_train_log, y_test_log = train_test_split(X, y, test_size=0.1)

model_log = LogisticRegression(multi_class = 'multinomial', solver = 'lbfgs', max_iter = 1000)
model_log.fit(X_train_log, y_train_log)

y_pred_log = model_log.predict(X_test_log)

accuracy_log = accuracy_score(y_test_log, y_pred_log)
print(accuracy_log)
# Out:
# 0.5028571428571429

# %%
kf = KFold(n_splits = 5, random_state = 1, shuffle=True)

cv_scores_log = cross_val_score(model_log, X, y, cv=kf)
avg_score_log = np.mean(cv_scores_log)
print(cv_scores_log)
print(avg_score_log)
# Out:
# [0.48857143 0.48571429 0.46857143 0.46285714 0.48857143]
# 0.4788571428571428

# %%
reverse_map = {idx: item for idx, item in enumerate(list(gene_df['OncotreeLineage'].unique()))}

coef_map = {}

coef = list(model_log.coef_)

for i in range(30):
    # Get indices of top 5 coefficients
    top_5_indices = sorted(range(len(coef[i])), key=lambda x: abs(coef[i][x]), reverse=True)[:3]
    # Map top 5 coefficients to their corresponding features
    top_5_features = [X.columns[index] for index in top_5_indices]
    # Store in coef_map
    coef_map[reverse_map[i]] = top_5_features

for category, top_5_features in coef_map.items():
    print(f"Top 3 features for {category}: {top_5_features}")
# Out:
# Top 5 features for Lung: ['WASIR2 (100132169)', 'EYA1 (2138)', 'CASC11 (100270680)']
# Top 5 features for Head and Neck: ['MIR1268A (100302233)', 'CHEK2P2 (646096)', 'RNVU1-17 (101954269)']
# Top 5 features for Ovary/Fallopian Tube: ['KLRC2 (3822)', 'ORM1 (5004)', 'UGT2B28 (54490)']
# Top 5 features for Breast: ['FAM230C (26080)', 'OR2T10 (127069)', 'OR2T11 (127077)']
# Top 5 features for Bone: ['CDKN2A (1029)', 'LINC01676 (101928476)', 'PRMT6 (55170)']
# Top 5 features for Bowel: ['ACOT1 (641371)', 'UGT2B17 (7367)', 'CDKN2A (1029)']
# Top 5 features for Lymphoid: ['AC244502.1 (105370401)', 'MIR4436A (100616399)', 'PRSS1 (5644)']
# Top 5 features for Skin: ['ORM1 (5004)', 'ACOT1 (641371)', 'WASIR2 (100132169)']
# Top 5 features for Uterus: ['CCL4L2 (9560)', 'CCL3L3 (414062)', 'MIR4275 (100422937)']
# Top 5 features for Eye: ['HLA-DQB1 (3119)', 'HLA-DQB1-AS1 (106480429)', 'HLA-DQA1 (3117)']
# Top 5 features for Esophagus/Stomach: ['CCL4L2 (9560)', 'CCL3L3 (414062)', 'UGT2B17 (7367)']
# Top 5 features for Pleura: ['CDKN2B (1030)', 'CDKN2B-AS1 (100048912)', 'CDKN2A (1029)']
# Top 5 features for CNS/Brain: ['FAM25E (643479)', 'BTNL3 (10917)', 'HLA-DQB1-AS1 (106480429)']
# Top 5 features for Pancreas: ['CCL3L3 (414062)', 'CCL4L2 (9560)', 'FAM230A (653203)']
# Top 5 features for Kidney: ['HLA-C (3107)', 'LINC02571 (105375015)', 'SMARCB1 (6598)']
# Top 5 features for Prostate: ['ORM1 (5004)', 'MAZ (4150)', 'PRRT2 (112476)']
# Top 5 features for Thyroid: ['CFHR1 (3078)', 'CFHR3 (10878)', 'LINC01239 (441389)']
# Top 5 features for Liver: ['CCL4L2 (9560)', 'CCL3L3 (414062)', 'FGF19 (9965)']
# Top 5 features for Testis: ['PLCZ1 (89869)', 'RERGL (79785)', 'CAPZA3 (93661)']
# Top 5 features for Myeloid: ['ADAM6 (8755)', 'CFHR3 (10878)', 'CFHR1 (3078)']
# Top 5 features for Peripheral Nervous System: ['MYCNOS (10408)', 'MYCNUT (103752554)', 'MYCN (4613)']
# Top 5 features for Soft Tissue: ['BTNL3 (10917)', 'AC013460.1 (100506274)', 'AC068481.1 (101929452)']
# Top 5 features for Bladder/Urinary Tract: ['CDKN2A (1029)', 'MTAP (4507)', 'LINC00581 (100874531)']
# Top 5 features for Biliary Tract: ['WASIR2 (100132169)', 'CDKN2B (1030)', 'FAM25E (643479)']
# Top 5 features for Vulva/Vagina: ['UGT2B17 (7367)', 'CFHR1 (3078)', 'CFHR3 (10878)']
# Top 5 features for Cervix: ['ADAM6 (8755)', 'FAM30A (9834)', 'CDKN2A (1029)']
# Top 5 features for Normal: ['MEF2C-AS1 (101929423)', 'HLA-DQB1-AS1 (106480429)', 'ADAM6 (8755)']
# Top 5 features for Fibroblast: ['MEF2C-AS1 (101929423)', 'SEMA6D (80031)', 'CTSW (1521)']
# Top 5 features for Adrenal Gland: ['OR2T10 (127069)', 'FAM30A (9834)', 'MIR4539 (100616374)']
# Top 5 features for Other: ['CEACAM4 (1089)', 'CEACAM7 (1087)', 'CEACAM5 (1048)']

# %%
df_coef = pd.DataFrame(coef_map)

df_coef = df_coef.transpose()

df_coef.fillna('', inplace=True)

df_coef.reset_index(inplace=True)

df_coef.rename(columns={'index': 'Cell Lineage'}, inplace=True)

new_columns = {col: f"#{i+1} Most Weighted Gene" for i, col in enumerate(df_coef.columns[1:])}
df_coef.rename(columns=new_columns, inplace=True)

df_coef
# Out:
#                  Cell Lineage   #1 Most Weighted Gene  \
# 0                        Lung      WASIR2 (100132169)
# 1               Head and Neck    MIR1268A (100302233)
# 2        Ovary/Fallopian Tube            KLRC2 (3822)
# 3                      Breast         FAM230C (26080)
# 4                        Bone           CDKN2A (1029)
# 5                       Bowel          ACOT1 (641371)
# 6                    Lymphoid  AC244502.1 (105370401)
# 7                        Skin             ORM1 (5004)
# 8                      Uterus           CCL4L2 (9560)
# 9                         Eye         HLA-DQB1 (3119)
# 10          Esophagus/Stomach           CCL4L2 (9560)
# 11                     Pleura           CDKN2B (1030)
# 12                  CNS/Brain         FAM25E (643479)
# 13                   Pancreas         CCL3L3 (414062)
# 14                     Kidney            HLA-C (3107)
# 15                   Prostate             ORM1 (5004)
# 16                    Thyroid            CFHR1 (3078)
# 17                      Liver           CCL4L2 (9560)
# 18                     Testis           PLCZ1 (89869)
# 19                    Myeloid            ADAM6 (8755)
# 20  Peripheral Nervous System          MYCNOS (10408)
# 21                Soft Tissue           BTNL3 (10917)
# 22      Bladder/Urinary Tract           CDKN2A (1029)
# 23              Biliary Tract      WASIR2 (100132169)
# 24               Vulva/Vagina          UGT2B17 (7367)
# 25                     Cervix            ADAM6 (8755)
# 26                     Normal   MEF2C-AS1 (101929423)
# 27                 Fibroblast   MEF2C-AS1 (101929423)
# 28              Adrenal Gland         OR2T10 (127069)
# 29                      Other          CEACAM4 (1089)
#
#        #2 Most Weighted Gene     #3 Most Weighted Gene
# 0                EYA1 (2138)        CASC11 (100270680)
# 1           CHEK2P2 (646096)      RNVU1-17 (101954269)
# 2                ORM1 (5004)           UGT2B28 (54490)
# 3            OR2T10 (127069)           OR2T11 (127077)
# 4      LINC01676 (101928476)             PRMT6 (55170)
# 5             UGT2B17 (7367)             CDKN2A (1029)
# 6       MIR4436A (100616399)              PRSS1 (5644)
# 7             ACOT1 (641371)        WASIR2 (100132169)
# 8            CCL3L3 (414062)       MIR4275 (100422937)
# 9   HLA-DQB1-AS1 (106480429)           HLA-DQA1 (3117)
# 10           CCL3L3 (414062)            UGT2B17 (7367)
# 11    CDKN2B-AS1 (100048912)             CDKN2A (1029)
# 12             BTNL3 (10917)  HLA-DQB1-AS1 (106480429)
# 13             CCL4L2 (9560)          FAM230A (653203)
# 14     LINC02571 (105375015)            SMARCB1 (6598)
# 15                MAZ (4150)            PRRT2 (112476)
# 16             CFHR3 (10878)        LINC01239 (441389)
# 17           CCL3L3 (414062)              FGF19 (9965)
# 18             RERGL (79785)            CAPZA3 (93661)
# 19             CFHR3 (10878)              CFHR1 (3078)
# 20        MYCNUT (103752554)               MYCN (4613)
# 21    AC013460.1 (100506274)    AC068481.1 (101929452)
# 22               MTAP (4507)     LINC00581 (100874531)
# 23             CDKN2B (1030)           FAM25E (643479)
# 24              CFHR1 (3078)             CFHR3 (10878)
# 25             FAM30A (9834)             CDKN2A (1029)
# 26  HLA-DQB1-AS1 (106480429)              ADAM6 (8755)
# 27            SEMA6D (80031)               CTSW (1521)
# 28             FAM30A (9834)       MIR4539 (100616374)
# 29            CEACAM7 (1087)            CEACAM5 (1048)
