# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score

from sklearn.linear_model import LogisticRegression


import matplotlib.pyplot as plt

# %%
gene_effect_df = pd.read_csv("GeneCN.csv").rename(columns = {'Unnamed: 0': 'ModelID'})
model_df = pd.read_csv("Model.csv")

merged_df = pd.merge(gene_effect_df, model_df[['ModelID', 'OncotreePrimaryDisease']], on='ModelID', how='inner')

new_cols = gene_effect_df.columns.tolist()
new_cols.insert(1, "OncotreePrimaryDisease")

gene_df = merged_df[new_cols]

# %%
categorical_mapping = {item: idx for idx, item in enumerate(list(gene_df['OncotreePrimaryDisease'].unique()))}
gene_df['Disease as Number'] = gene_df['OncotreePrimaryDisease'].map(categorical_mapping)

gene_df = gene_df.fillna(0)

gene_df = gene_df.set_index('ModelID')

# gene_df.head()
# Out:
# C:\Users\adenl\AppData\Local\Temp\ipykernel_20540\369468172.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gene_df['Disease as Number'] = gene_df['OncotreePrimaryDisease'].map(categorical_mapping)

# %%
X = gene_df.drop(columns = ['Disease as Number', 'OncotreePrimaryDisease'])
y = gene_df['Disease as Number']

# %%
X_train_log, X_test_log, y_train_log, y_test_log = train_test_split(X, y, test_size=0.1)

model_log = LogisticRegression(multi_class = 'multinomial', solver = 'lbfgs', max_iter = 1000)
model_log.fit(X_train_log, y_train_log)

y_pred_log = model_log.predict(X_test_log)

accuracy_log = accuracy_score(y_test_log, y_pred_log)
print(accuracy_log)
# Out:
# 0.4514285714285714

# %%
kf = KFold(n_splits = 5, random_state = 1, shuffle=True)

cv_scores_log = cross_val_score(model_log, X, y, cv=kf)
avg_score_log = np.mean(cv_scores_log)
print(cv_scores_log)
print(avg_score_log)
# Out:
# [0.47142857 0.46       0.43714286 0.44285714 0.45428571]
# 0.4531428571428572

# %%
reverse_map = {idx: item for idx, item in enumerate(list(gene_df['OncotreePrimaryDisease'].unique()))}

coef_map = {}

coef = list(model_log.coef_)

for i in range(80):
    # Get indices of top 5 coefficients
    top_5_indices = sorted(range(len(coef[i])), key=lambda x: abs(coef[i][x]), reverse=True)[:5]
    # Map top 5 coefficients to their corresponding features
    top_5_features = [X.columns[index] for index in top_5_indices]
    # Store in coef_map
    coef_map[reverse_map[i]] = top_5_features

for category, top_5_features in coef_map.items():
    print(f"Top 5 features for {category}: {top_5_features}")
# Out:
# Top 5 features for Lung Neuroendocrine Tumor: ['OR2T10 (127069)', 'OR2T11 (127077)', 'MYC (4609)', 'EYA1 (2138)', 'CASC11 (100270680)']
# Top 5 features for Head and Neck Squamous Cell Carcinoma: ['MIR1268A (100302233)', 'RNVU1-17 (101954269)', 'RNVU1-18 (26863)', 'CHEK2P2 (646096)', 'CDH10 (1008)']
# Top 5 features for Ovarian Epithelial Tumor: ['ORM1 (5004)', 'KLRC2 (3822)', 'UGT2B28 (54490)', 'KIR2DL4 (3805)', 'OR2T10 (127069)']
# Top 5 features for Invasive Breast Carcinoma: ['OR2T10 (127069)', 'OR2T11 (127077)', 'MIR3675 (100500876)', 'FAM230C (26080)', 'CHEK2P2 (646096)']
# Top 5 features for Osteosarcoma: ['FAM230C (26080)', 'CCT8L2 (150160)', 'TPTEP1 (387590)', 'XKR3 (150165)', 'TPTE (7179)']
# Top 5 features for Colorectal Adenocarcinoma: ['UGT2B17 (7367)', 'ACOT1 (641371)', 'CDKN2A (1029)', 'CDKN2B (1030)', 'ADAM6 (8755)']
# Top 5 features for Non-Hodgkin Lymphoma: ['MIR4436A (100616399)', 'AC093655.1 (105375341)', 'ADAM6 (8755)', 'CCL4L2 (9560)', 'CCL3L3 (414062)']
# Top 5 features for Melanoma: ['ORM1 (5004)', 'ACOT1 (641371)', 'CDKN2A (1029)', 'PRSS2 (5645)', 'PRSS1 (5644)']
# Top 5 features for Endometrial Carcinoma: ['CCL4L2 (9560)', 'CCL3L3 (414062)', 'MEF2C-AS1 (101929423)', 'MIR4275 (100422937)', 'LINC02261 (101929199)']
# Top 5 features for Mature B-Cell Neoplasms: ['MIR1268A (100302233)', 'LCE1D (353134)', 'ADAM6 (8755)', 'CHEK2P2 (646096)', 'MIR4539 (100616374)']
# Top 5 features for Ocular Melanoma: ['WASIR2 (100132169)', 'HLA-DQB1 (3119)', 'HLA-DQB1-AS1 (106480429)', 'MIR541 (100126308)', 'MIR409 (574413)']
# Top 5 features for Esophagogastric Adenocarcinoma: ['CCL3L3 (414062)', 'CCL4L2 (9560)', 'MIR548BB (103504735)', 'UGT2B17 (7367)', 'CHEK2P2 (646096)']
# Top 5 features for Non-Small Cell Lung Cancer: ['WASIR2 (100132169)', 'MIR378D1 (100616201)', 'LINC01804 (101926966)', 'DDX1 (1653)', 'NBAS (51594)']
# Top 5 features for Pleural Mesothelioma: ['CDKN2B (1030)', 'CDKN2B-AS1 (100048912)', 'CDKN2A (1029)', 'IFNA2 (3440)', 'CFHR3 (10878)']
# Top 5 features for Diffuse Glioma: ['CDKN2A (1029)', 'CDKN2B (1030)', 'CDKN2C (1031)', 'CDKN2B-AS1 (100048912)', 'DMRTA1 (63951)']
# Top 5 features for Esophageal Squamous Cell Carcinoma: ['GRB7 (2886)', 'MIR548K (100313770)', 'MIR4728 (100616132)', 'ERBB2 (2064)', 'MIEN1 (84299)']
# Top 5 features for Ewing Sarcoma: ['CDKN2A (1029)', 'CDKN2B (1030)', 'CDKN2B-AS1 (100048912)', 'MTAP (4507)', 'ORM1 (5004)']
# Top 5 features for Merkel Cell Carcinoma: ['OR4P4 (81300)', 'OR4S2 (219431)', 'OR4C11 (219429)', 'WASIR2 (100132169)', 'TMEM81 (388730)']
# Top 5 features for Non-Cancerous: ['CCL3L3 (414062)', 'CCL4L2 (9560)', 'MEF2C-AS1 (101929423)', 'MIR1268A (100302233)', 'CDKN2A (1029)']
# Top 5 features for Pancreatic Adenocarcinoma: ['CCL4L2 (9560)', 'CCL3L3 (414062)', 'FAM230A (653203)', 'SMAD4 (4089)', 'ADAM6 (8755)']
# Top 5 features for T-Lymphoblastic Leukemia/Lymphoma: ['PRSS1 (5644)', 'PRSS2 (5645)', 'AC244502.1 (105370401)', 'MTRNR2L6 (100463482)', 'CDKN2A (1029)']
# Top 5 features for Renal Cell Carcinoma: ['OR4S2 (219431)', 'OR4P4 (81300)', 'OR4C11 (219429)', 'CFHR3 (10878)', 'CFHR1 (3078)']
# Top 5 features for Prostate Adenocarcinoma: ['ORM1 (5004)', 'KCNK12 (56660)', 'MSH2-OT1 (644093)', 'CCL4L2 (9560)', 'MSH2 (4436)']
# Top 5 features for Anaplastic Thyroid Cancer: ['CFHR1 (3078)', 'CFHR3 (10878)', 'CEACAMP10 (284344)', 'ADAM6 (8755)', 'PSG9 (5678)']
# Top 5 features for Hepatocellular Carcinoma: ['CCL4L2 (9560)', 'CCL3L3 (414062)', 'FGF19 (9965)', 'CCND1 (595)', 'LTO1 (220064)']
# Top 5 features for Non-Seminomatous Germ Cell Tumor: ['PLEKHA5 (54477)', 'SYT10 (341359)', 'YARS2 (51067)', 'DNM1L (10059)', 'PKP2 (5318)']
# Top 5 features for Mature T and NK Neoplasms: ['LINC01482 (101928104)', 'CHEK2P2 (646096)', 'PDE5A (8654)', 'MIR1268A (100302233)', 'MTRNR2L6 (100463482)']
# Top 5 features for Myeloproliferative Neoplasms: ['MIR4275 (100422937)', 'LINC02261 (101929199)', 'MEF2C-AS1 (101929423)', 'MTAP (4507)', 'CDKN2A (1029)']
# Top 5 features for Nerve Sheath Tumor: ['OR4S2 (219431)', 'OR4P4 (81300)', 'OR4C11 (219429)', 'OR4C6 (219432)', 'PDGFRA (5156)']
# Top 5 features for Neuroblastoma: ['MYCNOS (10408)', 'MYCNUT (103752554)', 'MYCN (4613)', 'LINC01804 (101926966)', 'CDKN2A (1029)']
# Top 5 features for Acute Myeloid Leukemia: ['UGT2B17 (7367)', 'ADAM6 (8755)', 'FAM30A (9834)', 'MIR4436A (100616399)', 'TRIM48 (79097)']
# Top 5 features for Undifferentiated Pleomorphic Sarcoma/Malignant Fibrous Histiocytoma/High-Grade Spindle Cell Sarcoma: ['MIR100 (406892)', 'MIR125B1 (406911)', 'BLID (414899)', 'MIRLET7A2 (406882)', 'MIR4483 (100616162)']
# Top 5 features for Breast Ductal Carcinoma In Situ: ['NEUROD2 (4761)', 'PPP1R1B (84152)', 'CDK12 (51755)', 'STARD3 (10948)', 'GRB7 (2886)']
# Top 5 features for Bladder Urothelial Carcinoma: ['CDKN2A (1029)', 'MTAP (4507)', 'LINC00581 (100874531)', 'SOX4 (6659)', 'CDKAL1 (54901)']
# Top 5 features for Intraductal Papillary Neoplasm of the Bile Duct: ['CDKN2B (1030)', 'OR4C11 (219429)', 'OR4P4 (81300)', 'OR4S2 (219431)', 'WASIR2 (100132169)']
# Top 5 features for Rhabdoid Cancer: ['LINC02571 (105375015)', 'HLA-C (3107)', 'SMARCB1 (6598)', 'HLA-DQB1 (3119)', 'C22orf15 (150248)']
# Top 5 features for Pancreatic Neuroendocrine Tumor: ['CAND1 (55832)', 'LINC02408 (100507175)', 'LINC02420 (102724433)', 'GRIP1 (23426)', 'HELB (92797)']
# Top 5 features for Meningothelial Tumor: ['SLC2A11 (66035)', 'MIF (4282)', 'DERL3 (91319)', 'SMARCB1 (6598)', 'FAM230I (388882)']
# Top 5 features for Chondrosarcoma: ['PRMT6 (55170)', 'LINC01676 (101928476)', 'AMY1B (277)', 'AC092506.1 (100129138)', 'SEMA6D (80031)']
# Top 5 features for Embryonal Tumor: ['FAM25E (643479)', 'HLA-DQA1 (3117)', 'BTNL3 (10917)', 'HLA-DQB1-AS1 (106480429)', 'OR4C11 (219429)']
# Top 5 features for Prostate Neuroendocrine Carcinoma: ['CCL3L3 (414062)', 'CCL4L2 (9560)', 'LMLN-AS1 (100873947)', 'ANKRD18DP (348840)', 'MAZ (4150)']
# Top 5 features for Leiomyosarcoma: ['OR4S2 (219431)', 'OR4P4 (81300)', 'OR4C11 (219429)', 'OR4C6 (219432)', 'APBA2 (321)']
# Top 5 features for Squamous Cell Carcinoma of the Vulva/Vagina: ['MIR21 (406991)', 'RELT (84957)', 'CCT8L2 (150160)', 'ARHGEF17 (9828)', 'P2RY6 (5031)']
# Top 5 features for Small Bowel Cancer: ['HPR (3250)', 'TBC1D3J (100510707)', 'OR5P2 (120065)', 'TXNL4B (54957)', 'RNVU1-17 (101954269)']
# Top 5 features for Cervical Squamous Cell Carcinoma: ['ADAM6 (8755)', 'CDKN2A (1029)', 'FAM30A (9834)', 'CDKN2B (1030)', 'CDKN2B-AS1 (100048912)']
# Top 5 features for Uterine Sarcoma/Mesenchymal: ['OR4S2 (219431)', 'OR4P4 (81300)', 'OR4C11 (219429)', 'OR4C6 (219432)', 'OR2T10 (127069)']
# Top 5 features for Rhabdomyosarcoma: ['AC013460.1 (100506274)', 'AC068481.1 (101929452)', 'BTNL3 (10917)', 'LINC00298 (339788)', 'AC007463.1 (101929551)']
# Top 5 features for Well-Differentiated Thyroid Cancer: ['CCL3L3 (414062)', 'CCL4L2 (9560)', 'CDKN2B-AS1 (100048912)', 'LINC01239 (441389)', 'DMRTA1 (63951)']
# Top 5 features for Ovarian Cancer, Other: ['LINC01445 (102723605)', 'VSTM2A-OT1 (285878)', 'VSTM2A (222008)', 'SEC61G (23480)', 'VOPP1 (81552)']
# Top 5 features for Bladder Squamous Cell Carcinoma: ['CSH2 (1443)', 'GH2 (2689)', 'CSH1 (1442)', 'LINC01925 (105376854)', 'LINC01998 (107986046)']
# Top 5 features for Hepatoblastoma: ['CFHR1 (3078)', 'CFHR3 (10878)', 'HLA-B (3106)', 'MIR6891 (102465537)', 'ADAM6 (8755)']
# Top 5 features for Small Cell Carcinoma of the Cervix: ['UBE2T (29089)', 'MIR6739 (102466724)', 'IPO9 (55705)', 'SHISA4 (149345)', 'ELF3 (1999)']
# Top 5 features for Gestational Trophoblastic Disease: ['OR2T10 (127069)', 'FAM30A (9834)', 'MIR4539 (100616374)', 'MIR4507 (100616135)', 'MIR4538 (100616276)']
# Top 5 features for Adrenocortical Carcinoma: ['MIR4436A (100616399)', 'ACOT1 (641371)', 'HLA-C (3107)', 'LINC02571 (105375015)', 'TBC1D3J (100510707)']
# Top 5 features for B-Lymphoblastic Leukemia/Lymphoma: ['CDK4 (1019)', 'MIR6759 (102466729)', 'TSPAN31 (6302)', 'MARCHF9 (92979)', 'AGAP2 (116986)']
# Top 5 features for Liposarcoma: ['CFHR1 (3078)', 'CFHR3 (10878)', 'CDKN2A (1029)', 'CDKN2B (1030)', 'WASIR2 (100132169)']
# Top 5 features for Hepatocellular Carcinoma plus Intrahepatic Cholangiocarcinoma: ['CFHR1 (3078)', 'CFHR3 (10878)', 'ADAM6 (8755)', 'TOLLIP-AS1 (255512)', 'DMRTA1 (63951)']
# Top 5 features for Cervical Adenocarcinoma: ['MIR7973-2 (102465855)', 'MIR7973-1 (102466250)', 'GLDN (342035)', 'ZDHHC11B (653082)', 'DMXL2 (23312)']
# Top 5 features for Chordoma: ['AC011095.1 (339298)', 'ZNF516-DT (400658)', 'AC018413.1 (101927989)', 'ZNF516 (9658)', 'NBAS (51594)']
# Top 5 features for Glassy Cell Carcinoma of the Cervix: ['LINC00457 (100874179)', 'LINC02261 (101929199)', 'MIR4275 (100422937)', 'HLA-C (3107)', 'LINC02571 (105375015)']
# Top 5 features for Retinoblastoma: ['ATP1A3 (478)', 'GRIK5 (2901)', 'CEACAM5 (1048)', 'CEACAM6 (4680)', 'CEACAM7 (1087)']
# Top 5 features for Hodgkin Lymphoma: ['MIR570 (693155)', 'MMP7 (4316)', 'MMP20 (9313)', 'BIRC2 (329)', 'AP001830.1 (101928424)']
# Top 5 features for Extra Gonadal Germ Cell Tumor: ['EGFR (1956)', 'NUPR2 (389493)', 'CHCHD2 (51142)', 'PHKG1 (5260)', 'SUMF2 (25870)']
# Top 5 features for Adenosquamous Carcinoma of the Pancreas: ['MIR4539 (100616374)', 'MIR4507 (100616135)', 'MIR4538 (100616276)', 'MIR4537 (100616422)', 'ADAM6 (8755)']
# Top 5 features for Cutaneous Squamous Cell Carcinoma: ['HLA-DQA1 (3117)', 'HLA-DQB1-AS1 (106480429)', 'HLA-DQB1 (3119)', 'WASIR2 (100132169)', 'MIRLET7E (406887)']
# Top 5 features for Hereditary Spherocytosis: ['MMP11 (4320)', 'CCL3L3 (414062)', 'CCL4L2 (9560)', 'CABIN1 (23523)', 'NEGR1-IT1 (100852409)']
# Top 5 features for Medullary Thyroid Cancer: ['BCL2L14 (79370)', 'LRP6 (4040)', 'MANSC1 (54682)', 'LOH12CR2 (503693)', 'BORCS5 (118426)']
# Top 5 features for Intracholecystic Papillary Neoplasm: ['HLA-DQB1-AS1 (106480429)', 'TOB2 (10766)', 'TEF (7008)', 'ZC3H7B (23264)', 'RANGAP1 (5905)']
# Top 5 features for Urethral Cancer: ['CHEK2P2 (646096)', 'BX284668.5 (105376805)', 'RNU1-2 (26870)', 'BX284668.2 (112267871)', 'BTNL3 (10917)']
# Top 5 features for Epithelioid Sarcoma: ['CFHR3 (10878)', 'CFHR1 (3078)', 'DEFA5 (1670)', 'DEFA3 (1668)', 'ADAM6 (8755)']
# Top 5 features for Ampullary Carcinoma: ['ADAM6 (8755)', 'LINC01239 (441389)', 'DMRTA1 (63951)', 'TUBA3E (112714)', 'APOBEC3B (9582)']
# Top 5 features for Ovarian Germ Cell Tumor: ['CFHR1 (3078)', 'CFHR3 (10878)', 'MIR3683 (100500886)', 'CASTOR2 (729438)', 'KLRC2 (3822)']
# Top 5 features for Synovial Sarcoma: ['ZNF257 (113835)', 'KCNV2 (169522)', 'VLDLR-AS1 (401491)', 'VLDLR (7436)', 'PUM3 (9933)']
# Top 5 features for Mucosal Melanoma of the Vulva/Vagina: ['ZNF716 (441234)', 'AC099654.1 (105375297)', 'MIR3147 (100422939)', 'AC092447.5 (101928401)', 'AC095038.4 (102723684)']
# Top 5 features for Mixed Cervical Carcinoma: ['CDKN2B-AS1 (100048912)', 'CDKN2B (1030)', 'CDKN2A (1029)', 'ANKRD36B (57730)', 'SLC6A19 (340024)']
# Top 5 features for Acute Leukemias of Ambiguous Lineage: ['GLI2 (2736)', 'LINC00114 (400866)', 'AP001042.3 (101928398)', 'LINC01700 (101928435)', 'ETS2 (2114)']
# Top 5 features for Poorly Differentiated Thyroid Cancer: ['CFHR1 (3078)', 'CFHR3 (10878)', 'ADAM6 (8755)', 'TUBA3E (112714)', 'MTAP (4507)']
# Top 5 features for Myelodysplastic Syndromes: ['CFHR3 (10878)', 'CFHR1 (3078)', 'MIR4477B (100616194)', 'MIR876 (100126310)', 'MIR873 (100126316)']
# Top 5 features for Head and Neck Carcinoma, Other: ['ALDH8A1 (64577)', 'MIR3662 (100500880)', 'HBS1L (10767)', 'MYB (4602)', 'MIR548A2 (693126)']
# Top 5 features for Fibrosarcoma: ['USP17L2 (377630)', 'CFHR1 (3078)', 'CFHR3 (10878)', 'FBXL2 (25827)', 'OR4N2 (390429)']

# %%
df_coef = pd.DataFrame(coef_map)

df_coef = df_coef.transpose()

df_coef.fillna('', inplace=True)

df_coef.reset_index(inplace=True)

df_coef.rename(columns={'index': 'Primary Disease'}, inplace=True)

new_columns = {col: f"#{i+1} Most Weighted Gene" for i, col in enumerate(df_coef.columns[1:])}
df_coef.rename(columns=new_columns, inplace=True)

df_coef
# Out:
#                           Primary Disease #1 Most Weighted Gene  \
# 0               Lung Neuroendocrine Tumor       OR2T10 (127069)
# 1   Head and Neck Squamous Cell Carcinoma  MIR1268A (100302233)
# 2                Ovarian Epithelial Tumor           ORM1 (5004)
# 3               Invasive Breast Carcinoma       OR2T10 (127069)
# 4                            Osteosarcoma       FAM230C (26080)
# ..                                    ...                   ...
# 75   Acute Leukemias of Ambiguous Lineage           GLI2 (2736)
# 76   Poorly Differentiated Thyroid Cancer          CFHR1 (3078)
# 77              Myelodysplastic Syndromes         CFHR3 (10878)
# 78         Head and Neck Carcinoma, Other       ALDH8A1 (64577)
# 79                           Fibrosarcoma      USP17L2 (377630)
#
#    #2 Most Weighted Gene   #3 Most Weighted Gene  #4 Most Weighted Gene  \
# 0        OR2T11 (127077)              MYC (4609)            EYA1 (2138)
# 1   RNVU1-17 (101954269)        RNVU1-18 (26863)       CHEK2P2 (646096)
# 2           KLRC2 (3822)         UGT2B28 (54490)         KIR2DL4 (3805)
# 3        OR2T11 (127077)     MIR3675 (100500876)        FAM230C (26080)
# 4        CCT8L2 (150160)         TPTEP1 (387590)          XKR3 (150165)
# ..                   ...                     ...                    ...
# 75    LINC00114 (400866)  AP001042.3 (101928398)  LINC01700 (101928435)
# 76         CFHR3 (10878)            ADAM6 (8755)        TUBA3E (112714)
# 77          CFHR1 (3078)    MIR4477B (100616194)     MIR876 (100126310)
# 78   MIR3662 (100500880)           HBS1L (10767)             MYB (4602)
# 79          CFHR1 (3078)           CFHR3 (10878)          FBXL2 (25827)
#
#    #5 Most Weighted Gene
# 0     CASC11 (100270680)
# 1           CDH10 (1008)
# 2        OR2T10 (127069)
# 3       CHEK2P2 (646096)
# 4            TPTE (7179)
# ..                   ...
# 75           ETS2 (2114)
# 76           MTAP (4507)
# 77    MIR873 (100126316)
# 78     MIR548A2 (693126)
# 79        OR4N2 (390429)
#
# [80 rows x 6 columns]
