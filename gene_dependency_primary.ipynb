# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score

from sklearn.linear_model import LogisticRegression


import matplotlib.pyplot as plt

# %%
gene_effect_df = pd.read_csv("CRISPRGeneDependency.csv").rename(columns = {'Unnamed: 0': 'ModelID'})
model_df = pd.read_csv("Model.csv")

merged_df = pd.merge(gene_effect_df, model_df[['ModelID', 'OncotreePrimaryDisease']], on='ModelID', how='inner')

new_cols = gene_effect_df.columns.tolist()
new_cols.insert(1, "OncotreePrimaryDisease")

gene_df = merged_df[new_cols]

# %%
categorical_mapping = {item: idx for idx, item in enumerate(list(gene_df['OncotreePrimaryDisease'].unique()))}
gene_df['Disease as Number'] = gene_df['OncotreePrimaryDisease'].map(categorical_mapping)

gene_df = gene_df.fillna(0)

gene_df = gene_df.set_index('ModelID')

# gene_df.head()
# Out:
# C:\Users\adenl\AppData\Local\Temp\ipykernel_23748\369468172.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gene_df['Disease as Number'] = gene_df['OncotreePrimaryDisease'].map(categorical_mapping)

# %%
X = gene_df.drop(columns = ['Disease as Number', 'OncotreePrimaryDisease'])
y = gene_df['Disease as Number']

# %%
X_train_log, X_test_log, y_train_log, y_test_log = train_test_split(X, y, test_size=0.1)

model_log = LogisticRegression(multi_class = 'multinomial', solver = 'lbfgs', max_iter = 1000)
model_log.fit(X_train_log, y_train_log)

y_pred_log = model_log.predict(X_test_log)

accuracy_log = accuracy_score(y_test_log, y_pred_log)
print(accuracy_log)
# Out:
# 0.6

# %%
kf = KFold(n_splits = 5, random_state = 1, shuffle=True)

cv_scores_log = cross_val_score(model_log, X, y, cv=kf)
avg_score_log = np.mean(cv_scores_log)
print(cv_scores_log)
print(avg_score_log)
# Out:
# [0.61363636 0.55       0.62727273 0.62272727 0.62727273]
# 0.6081818181818182

# %%
reverse_map = {idx: item for idx, item in enumerate(list(gene_df['OncotreePrimaryDisease'].unique()))}

coef_map = {}

coef = list(model_log.coef_)

for i in range(72):
    # Get indices of top 5 coefficients
    top_5_indices = sorted(range(len(coef[i])), key=lambda x: abs(coef[i][x]), reverse=True)[:5]
    # Map top 5 coefficients to their corresponding features
    top_5_features = [X.columns[index] for index in top_5_indices]
    # Store in coef_map
    coef_map[reverse_map[i]] = top_5_features

# Print the coef_map
for category, top_5_features in coef_map.items():
    print(f"Top 5 features for {category}: {top_5_features}")
# Out:
# Top 5 features for Ovarian Epithelial Tumor: ['PAX8 (7849)', 'PARD6B (84612)', 'STRAP (11171)', 'PARD3 (56288)', 'STRIP1 (85369)']
# Top 5 features for Acute Myeloid Leukemia: ['MYB (4602)', 'SPI1 (6688)', 'CCND1 (595)', 'ZEB2 (9839)', 'CBFB (865)']
# Top 5 features for Colorectal Adenocarcinoma: ['CTNNB1 (1499)', 'TCF7L2 (6934)', 'CHMP4B (128866)', 'FERMT2 (10979)', 'GPX4 (2879)']
# Top 5 features for Bladder Urothelial Carcinoma: ['SOX4 (6659)', 'FAM50A (9130)', 'PPARG (5468)', 'ZNF143 (7702)', 'RXRA (6256)']
# Top 5 features for Non-Small Cell Lung Cancer: ['NFE2L2 (4780)', 'UROD (7389)', 'SMARCA2 (6595)', 'RPP25L (138716)', 'TMX2 (51075)']
# Top 5 features for Invasive Breast Carcinoma: ['ZFX (7543)', 'UMPS (7372)', 'CUL2 (8453)', 'GATA3 (2625)', 'SPDEF (25803)']
# Top 5 features for Pancreatic Adenocarcinoma: ['KRAS (3845)', 'FLII (2314)', 'RAB10 (10890)', 'DOCK5 (80005)', 'DYNLL1 (8655)']
# Top 5 features for Mature B-Cell Neoplasms: ['POU2AF1 (5450)', 'GRB2 (2885)', 'PIM2 (11040)', 'MBNL1 (4154)', 'IRF4 (3662)']
# Top 5 features for Meningothelial Tumor: ['GRB2 (2885)', 'ELMO2 (63916)', 'CRK (1398)', 'ZFP36L1 (677)', 'HLX (3142)']
# Top 5 features for Diffuse Glioma: ['RPP25L (138716)', 'PRKAR1A (5573)', 'SNAP23 (8773)', 'VRK1 (7443)', 'FAM50A (9130)']
# Top 5 features for Sarcoma, NOS: ['DONSON (29980)', 'RPL12 (6136)', 'PSMD14 (10213)', 'CDC45 (8318)', 'CHAF1B (8208)']
# Top 5 features for Ewing Sarcoma: ['FLI1 (2313)', 'TRIM8 (81603)', 'STAG1 (10274)', 'CDK6 (1021)', 'ZEB2 (9839)']
# Top 5 features for Esophagogastric Adenocarcinoma: ['ARF1 (375)', 'PPP2R1A (5518)', 'CTNNB1 (1499)', 'RAB10 (10890)', 'TCF7L2 (6934)']
# Top 5 features for Mature T and NK Neoplasms: ['IKZF1 (10320)', 'PTPN2 (5771)', 'SBNO2 (22904)', 'KCTD5 (54442)', 'STAT3 (6774)']
# Top 5 features for Fibrosarcoma: ['ARHGAP1 (392)', 'DDX3X (1654)', 'NRAS (4893)', 'RCE1 (9986)', 'GRB2 (2885)']
# Top 5 features for Embryonal Tumor: ['SMARCB1 (6598)', 'MICOS10 (440574)', 'NXT1 (29107)', 'HSP90B1 (7184)', 'SEPSECS (51091)']
# Top 5 features for B-Lymphoblastic Leukemia/Lymphoma: ['EBF1 (1879)', 'PAX5 (5079)', 'ATP6V0A2 (23545)', 'MEF2C (4208)', 'PIK3CD (5293)']
# Top 5 features for Myeloproliferative Neoplasms: ['BCR (613)', 'GAB2 (9846)', 'ABL1 (25)', 'STAT5B (6777)', 'MYB (4602)']
# Top 5 features for Non-Hodgkin Lymphoma: ['ETS1 (2113)', 'NUP42 (11097)', 'PDAP1 (11333)', 'PMM2 (5373)', 'GCLM (2730)']
# Top 5 features for Neuroblastoma: ['ISL1 (3670)', 'MYC (4609)', 'LDB1 (8861)', 'ATP6V1G1 (9550)', 'GATA3 (2625)']
# Top 5 features for Osteosarcoma: ['PFN1 (5216)', 'SUB1 (10923)', 'PITRM1 (10531)', 'CDS2 (8760)', 'IRS1 (3667)']
# Top 5 features for Pleural Mesothelioma: ['EXT2 (2132)', 'FGFR1 (2260)', 'SNAP23 (8773)', 'XYLT2 (64132)', 'EXTL3 (2137)']
# Top 5 features for Prostate Adenocarcinoma: ['DDX3X (1654)', 'ATL2 (64225)', 'UMPS (7372)', 'TMEM127 (55654)', 'CAD (790)']
# Top 5 features for Adenosquamous Carcinoma of the Pancreas: ['YRDC (79693)', 'TFAP2A (7020)', 'CTNND1 (1500)', 'ARL10 (285598)', 'CTNNA1 (1495)']
# Top 5 features for Rhabdomyosarcoma: ['MYOD1 (4654)', 'MMGT1 (93380)', 'ACSL3 (2181)', 'CCND1 (595)', 'EMC2 (9694)']
# Top 5 features for Intracholecystic Papillary Neoplasm: ['PPCDC (60490)', 'ZEB1 (6935)', 'PTDSS1 (9791)', 'TAF5L (27097)', 'SREBF1 (6720)']
# Top 5 features for Leiomyosarcoma: ['RPP25L (138716)', 'KDM2A (22992)', 'MFN2 (9927)', 'CHMP5 (51510)', 'SLC38A2 (54407)']
# Top 5 features for Renal Cell Carcinoma: ['PAX8 (7849)', 'HNF1B (6928)', 'VHL (7428)', 'PARD6B (84612)', 'GET4 (51608)']
# Top 5 features for Head and Neck Squamous Cell Carcinoma: ['UBR5 (51366)', 'ITGAV (3685)', 'FERMT2 (10979)', 'STAG2 (10735)', 'RPP25L (138716)']
# Top 5 features for Anaplastic Thyroid Cancer: ['GRB2 (2885)', 'TRAIP (10293)', 'PTPN11 (5781)', 'CUL2 (8453)', 'YRDC (79693)']
# Top 5 features for Ampullary Carcinoma: ['SLC7A5 (8140)', 'MED16 (10025)', 'RFK (55312)', 'TGFBR1 (7046)', 'ATL2 (64225)']
# Top 5 features for Lung Neuroendocrine Tumor: ['ATP6V1G1 (9550)', 'CIT (11113)', 'COPG1 (22820)', 'ARF4 (378)', 'EFR3A (23167)']
# Top 5 features for Endometrial Carcinoma: ['PAX8 (7849)', 'NUP43 (348995)', 'CDK6 (1021)', 'WNK1 (65125)', 'WRN (7486)']
# Top 5 features for T-Lymphoblastic Leukemia/Lymphoma: ['GATA3 (2625)', 'MYB (4602)', 'NMNAT1 (64802)', 'CRAMP1 (57585)', 'SLC7A1 (6541)']
# Top 5 features for Intraductal Papillary Neoplasm of the Bile Duct: ['CBLL1 (79872)', 'TFAP4 (7023)', 'CDK6 (1021)', 'OR6C6 (283365)', 'STXBP3 (6814)']
# Top 5 features for Hepatocellular Carcinoma: ['NAA10 (8260)', 'SNAP23 (8773)', 'XYLT2 (64132)', 'XRN1 (54464)', 'ZWINT (11130)']
# Top 5 features for Melanoma: ['SOX10 (6663)', 'BRAF (673)', 'DUSP4 (1846)', 'GRB2 (2885)', 'PTPN11 (5781)']
# Top 5 features for Esophageal Squamous Cell Carcinoma: ['CCDC51 (79714)', 'FIS1 (51024)', 'SLC39A10 (57181)', 'SMARCA4 (6597)', 'HSPA13 (6782)']
# Top 5 features for Poorly Differentiated Thyroid Cancer: ['NAA10 (8260)', 'AXIN1 (8312)', 'LHX1 (3975)', 'BRAF (673)', 'MAP2K1 (5604)']
# Top 5 features for Myelodysplastic Syndromes: ['AXL (558)', 'GATA1 (2623)', 'LMO2 (4005)', 'NANS (54187)', 'SPI1 (6688)']
# Top 5 features for Cervical Squamous Cell Carcinoma: ['ZER1 (10444)', 'UBE3A (7337)', 'SETD1B (23067)', 'CDK6 (1021)', 'CFLAR (8837)']
# Top 5 features for Chondrosarcoma: ['CCNE2 (9134)', 'GUK1 (2987)', 'SUB1 (10923)', 'EIF4A1 (1973)', 'TM9SF3 (56889)']
# Top 5 features for Rhabdoid Cancer: ['SMARCB1 (6598)', 'SMARCD1 (6602)', 'DAXX (1616)', 'XYLT2 (64132)', 'PELO (53918)']
# Top 5 features for Breast Ductal Carcinoma In Situ: ['STAMBP (10617)', 'RNH1 (6050)', 'NAA10 (8260)', 'FITM2 (128486)', 'WBP4 (11193)']
# Top 5 features for Hepatoblastoma: ['TCF7L2 (6934)', 'HNF1A (6927)', 'SLC25A28 (81894)', 'FOXA2 (3170)', 'NR5A1 (2516)']
# Top 5 features for Hodgkin Lymphoma: ['STAT6 (6778)', 'IL13RA1 (3597)', 'IRF4 (3662)', 'CHUK (1147)', 'THAP1 (55145)']
# Top 5 features for Well-Differentiated Thyroid Cancer: ['COP1 (64326)', 'DET1 (55070)', 'RHOA (387)', 'ARHGEF5 (7984)', 'VPS45 (11311)']
# Top 5 features for Undifferentiated Pleomorphic Sarcoma/Malignant Fibrous Histiocytoma/High-Grade Spindle Cell Sarcoma: ['STK11 (6794)', 'WDR1 (9948)', 'CAP1 (10487)', 'HSPA14 (51182)', 'CNOT1 (23019)']
# Top 5 features for Bladder Squamous Cell Carcinoma: ['FOXO3B (2310)', 'TRIM49D1 (399939)', 'CDAN1 (146059)', 'TRIM9 (114088)', 'HSPA8 (3312)']
# Top 5 features for Uterine Sarcoma/Mesenchymal: ['APEX2 (27301)', 'ACO2 (50)', 'PPP2CA (5515)', 'BIRC6 (57448)', 'POC1A (25886)']
# Top 5 features for Urethral Cancer: ['FIS1 (51024)', 'GPX4 (2879)', 'GEN1 (348654)', 'EXT1 (2131)', 'SLC25A28 (81894)']
# Top 5 features for Synovial Sarcoma: ['SMARCE1 (6605)', 'SS18 (6760)', 'PIAS1 (8554)', 'SMARCB1 (6598)', 'VPS72 (6944)']
# Top 5 features for Retinoblastoma: ['OTX2 (5015)', 'MYCN (4613)', 'PPP1R12A (4659)', 'MYC (4609)', 'ISL2 (64843)']
# Top 5 features for Non-Cancerous: ['RAB6A (5870)', 'CD2BP2 (10421)', 'VPS54 (51542)', 'DHFR (1719)', 'MGAT1 (4245)']
# Top 5 features for Cutaneous Squamous Cell Carcinoma: ['SNAI2 (6591)', 'ATP6V0E1 (8992)', 'GAB1 (2549)', 'TP63 (8626)', 'EFR3A (23167)']
# Top 5 features for Mixed Cervical Carcinoma: ['BRIX1 (55299)', 'GINS3 (64785)', 'NELFB (25920)', 'CDH6 (1004)', 'ICE1 (23379)']
# Top 5 features for Ovarian Germ Cell Tumor: ['TP63 (8626)', 'SYF2 (25949)', 'NUP42 (11097)', 'TBCB (1155)', 'PDAP1 (11333)']
# Top 5 features for Squamous Cell Carcinoma of the Vulva/Vagina: ['SMARCB1 (6598)', 'STAMBP (10617)', 'ELMO2 (63916)', 'HSP90B1 (7184)', 'EMC3 (55831)']
# Top 5 features for Epithelioid Sarcoma: ['STX4 (6810)', 'NAA10 (8260)', 'CRTC3 (64784)', 'KLF5 (688)', 'STXBP3 (6814)']
# Top 5 features for Cervical Adenocarcinoma: ['ATP6V1B2 (526)', 'GREB1L (80000)', 'KMT2C (58508)', 'TFAP2C (7022)', 'MBD3 (53615)']
# Top 5 features for Gestational Trophoblastic Disease: ['YRDC (79693)', 'CHD4 (1108)', 'CDK4 (1019)', 'CDK6 (1021)', 'ATF4 (468)']
# Top 5 features for Merkel Cell Carcinoma: ['RIC8A (60626)', 'MITF (4286)', 'SOX10 (6663)', 'INPP5A (3632)', 'PRKCE (5581)']
# Top 5 features for Ocular Melanoma: ['HAUS5 (23354)', 'HYOU1 (10525)', 'ESF1 (51575)', 'HNRNPM (4670)', 'RPP21 (79897)']
# Top 5 features for Non-Seminomatous Germ Cell Tumor: ['CYP27B1 (1594)', 'FGFR1 (2260)', 'CDK6 (1021)', 'DAZAP1 (26528)', 'SNIP1 (79753)']
# Top 5 features for Liposarcoma: ['CSTF2 (1478)', 'UROS (7390)', 'BCL2 (596)', 'NFIB (4781)', 'SOX10 (6663)']
# Top 5 features for Breast Neoplasm, NOS: ['HDAC1 (3065)', 'TMEM41A (90407)', 'NUSAP1 (51203)', 'SYS1 (90196)', 'COPG1 (22820)']
# Top 5 features for Hepatocellular Carcinoma plus Intrahepatic Cholangiocarcinoma: ['ZER1 (10444)', 'TP63 (8626)', 'SPTY2D1 (144108)', 'IER3IP1 (51124)', 'TSC2 (7249)']
# Top 5 features for Glassy Cell Carcinoma of the Cervix: ['FDFT1 (2222)', 'DUSP4 (1846)', 'IRF4 (3662)', 'BRAF (673)', 'MITF (4286)']
# Top 5 features for Mucosal Melanoma of the Vulva/Vagina: ['GJA3 (2700)', 'YRDC (79693)', 'KDM8 (79831)', 'SAFB (6294)', 'TRIR (79002)']
# Top 5 features for Nerve Sheath Tumor: ['EIF2B5 (8893)', 'MED22 (6837)', 'RPLP2 (6181)', 'TFAP2C (7022)', 'DERL1 (79139)']
# Top 5 features for Extra Gonadal Germ Cell Tumor: ['GNB1 (2782)', 'EDF1 (8721)', 'ERBB3 (2065)', 'FIS1 (51024)', 'ATP6V0D1 (9114)']
# Top 5 features for Head and Neck Carcinoma, Other: ['ARIH1 (25820)', 'UBE2L3 (7332)', 'TPT1 (7178)', 'TGFBR2 (7048)', 'DHX9 (1660)']

# %%
df_coef = pd.DataFrame(coef_map)

df_coef = df_coef.transpose()

df_coef.fillna('', inplace=True)

df_coef.reset_index(inplace=True)

df_coef.rename(columns={'index': 'Primary Disease'}, inplace=True)

new_columns = {col: f"#{i+1} Most Weighted Gene" for i, col in enumerate(df_coef.columns[1:])}
df_coef.rename(columns=new_columns, inplace=True)

df_coef
# Out:
#                          Primary Disease #1 Most Weighted Gene  \
# 0               Ovarian Epithelial Tumor           PAX8 (7849)
# 1                 Acute Myeloid Leukemia            MYB (4602)
# 2              Colorectal Adenocarcinoma         CTNNB1 (1499)
# 3           Bladder Urothelial Carcinoma           SOX4 (6659)
# 4             Non-Small Cell Lung Cancer         NFE2L2 (4780)
# ..                                   ...                   ...
# 67   Glassy Cell Carcinoma of the Cervix          FDFT1 (2222)
# 68  Mucosal Melanoma of the Vulva/Vagina           GJA3 (2700)
# 69                    Nerve Sheath Tumor         EIF2B5 (8893)
# 70         Extra Gonadal Germ Cell Tumor           GNB1 (2782)
# 71        Head and Neck Carcinoma, Other         ARIH1 (25820)
#
#    #2 Most Weighted Gene #3 Most Weighted Gene #4 Most Weighted Gene  \
# 0         PARD6B (84612)         STRAP (11171)         PARD3 (56288)
# 1            SPI1 (6688)           CCND1 (595)           ZEB2 (9839)
# 2          TCF7L2 (6934)       CHMP4B (128866)        FERMT2 (10979)
# 3          FAM50A (9130)          PPARG (5468)         ZNF143 (7702)
# 4            UROD (7389)        SMARCA2 (6595)       RPP25L (138716)
# ..                   ...                   ...                   ...
# 67          DUSP4 (1846)           IRF4 (3662)            BRAF (673)
# 68          YRDC (79693)          KDM8 (79831)           SAFB (6294)
# 69          MED22 (6837)          RPLP2 (6181)         TFAP2C (7022)
# 70           EDF1 (8721)          ERBB3 (2065)          FIS1 (51024)
# 71         UBE2L3 (7332)           TPT1 (7178)         TGFBR2 (7048)
#
#    #5 Most Weighted Gene
# 0         STRIP1 (85369)
# 1             CBFB (865)
# 2            GPX4 (2879)
# 3            RXRA (6256)
# 4           TMX2 (51075)
# ..                   ...
# 67           MITF (4286)
# 68          TRIR (79002)
# 69         DERL1 (79139)
# 70       ATP6V0D1 (9114)
# 71           DHX9 (1660)
#
# [72 rows x 6 columns]
