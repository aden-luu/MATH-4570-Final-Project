# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score

from sklearn.linear_model import LogisticRegression


import matplotlib.pyplot as plt

# %%
gene_effect_df = pd.read_csv("GeneExpression.csv").rename(columns = {'Unnamed: 0': 'ModelID'})
model_df = pd.read_csv("Model.csv")

merged_df = pd.merge(gene_effect_df, model_df[['ModelID', 'OncotreePrimaryDisease']], on='ModelID', how='inner')

new_cols = gene_effect_df.columns.tolist()
new_cols.insert(1, "OncotreePrimaryDisease")

gene_df = merged_df[new_cols]

# %%
categorical_mapping = {item: idx for idx, item in enumerate(list(gene_df['OncotreePrimaryDisease'].unique()))}
gene_df['Disease as Number'] = gene_df['OncotreePrimaryDisease'].map(categorical_mapping)

gene_df = gene_df.fillna(0)

gene_df = gene_df.set_index('ModelID')

# gene_df.head()
# Out:
# C:\Users\adenl\AppData\Local\Temp\ipykernel_15036\369468172.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gene_df['Disease as Number'] = gene_df['OncotreePrimaryDisease'].map(categorical_mapping)

# %%
X = gene_df.drop(columns = ['Disease as Number', 'OncotreePrimaryDisease'])
y = gene_df['Disease as Number']

# %%
X_train_log, X_test_log, y_train_log, y_test_log = train_test_split(X, y, test_size=0.1)

model_log = LogisticRegression(multi_class = 'multinomial', solver = 'lbfgs', max_iter = 1000)
model_log.fit(X_train_log, y_train_log)

y_pred_log = model_log.predict(X_test_log)

accuracy_log = accuracy_score(y_test_log, y_pred_log)
print(accuracy_log)
# Out:
# 0.777027027027027

# %%
kf = KFold(n_splits = 5, random_state = 1, shuffle=True)

cv_scores_log = cross_val_score(model_log, X, y, cv=kf)
avg_score_log = np.mean(cv_scores_log)
print(cv_scores_log)
print(avg_score_log)
# Out:
# [0.74662162 0.77702703 0.76013514 0.72297297 0.73559322]
# 0.748469995419148

# %%
reverse_map = {idx: item for idx, item in enumerate(list(gene_df['OncotreePrimaryDisease'].unique()))}

coef_map = {}

coef = list(model_log.coef_)

for i in range(75):
    # Get indices of top 5 coefficients
    top_5_indices = sorted(range(len(coef[i])), key=lambda x: abs(coef[i][x]), reverse=True)[:5]
    # Map top 5 coefficients to their corresponding features
    top_5_features = [X.columns[index] for index in top_5_indices]
    # Store in coef_map
    coef_map[reverse_map[i]] = top_5_features

# Print the coef_map
for category, top_5_features in coef_map.items():
    print(f"Top 5 features for {category}: {top_5_features}")
# Out:
# Top 5 features for Non-Small Cell Lung Cancer: ['XAGE1A (653220)', 'XAGE1B (653067)', 'RNF212 (285498)', 'BST2 (684)', 'HOXB2 (3212)']
# Top 5 features for Embryonal Tumor: ['CHRNA9 (55584)', 'MGP (4256)', 'TSTD1 (100131187)', 'S100A4 (6275)', 'HENMT1 (113802)']
# Top 5 features for Melanoma: ['UCHL1 (7345)', 'MEST (4232)', 'LCP1 (3936)', 'S100B (6285)', 'GJA1 (2697)']
# Top 5 features for Intraductal Papillary Neoplasm of the Bile Duct: ['SPP1 (6696)', 'BMP4 (652)', 'PXDN (7837)', 'CFH (3075)', 'CPE (1363)']
# Top 5 features for Merkel Cell Carcinoma: ['XAGE1A (653220)', 'CA9 (768)', 'S100A1 (6271)', 'G0S2 (50486)', 'PAX8 (7849)']
# Top 5 features for Sarcoma, NOS: ['GCG (2641)', 'PAGE4 (9506)', 'SMR3B (10879)', 'FGF20 (26281)', 'CALB2 (794)']
# Top 5 features for Small Bowel Cancer: ['SPINK6 (404203)', 'CRIP1 (1396)', 'CYP24A1 (1591)', 'AKR1C2 (1646)', 'CDKN2A (1029)']
# Top 5 features for Cervical Adenocarcinoma: ['PRDX2 (7001)', 'IL33 (90865)', 'GREM1 (26585)', 'IL1B (3553)', 'FABP5 (2171)']
# Top 5 features for Leiomyosarcoma: ['PRAME (23532)', 'THY1 (7070)', 'VAMP5 (10791)', 'GREM1 (26585)', 'LAMC2 (3918)']
# Top 5 features for Anaplastic Thyroid Cancer: ['MMP1 (4312)', 'ALDH7A1 (501)', 'MTRNR2L12 (100462981)', 'MMP10 (4319)', 'MAGEA3 (4102)']
# Top 5 features for Bladder Squamous Cell Carcinoma: ['MMP7 (4316)', 'TSPAN8 (7103)', 'NOTUM (147111)', 'APCDD1 (147495)', 'ETFRF1 (144363)']
# Top 5 features for Ovarian Cancer, Other: ['BST2 (684)', 'COL6A3 (1293)', 'NEFL (4747)', 'THY1 (7070)', 'RPS4Y1 (6192)']
# Top 5 features for Meningothelial Tumor: ['GTSF1 (121355)', 'MMP1 (4312)', 'PRAME (23532)', 'AEBP1 (165)', 'EREG (2069)']
# Top 5 features for Undifferentiated Pleomorphic Sarcoma/Malignant Fibrous Histiocytoma/High-Grade Spindle Cell Sarcoma: ['LY6D (8581)', 'KRT13 (3860)', 'TM4SF4 (7104)', 'ALDH1A1 (216)', 'SFTA2 (389376)']
# Top 5 features for Hepatocellular Carcinoma plus Intrahepatic Cholangiocarcinoma: ['XAGE2 (9502)', 'CLDN6 (9074)', 'S100A6 (6277)', 'CGA (1081)', 'ERVH48-1 (90625)']
# Top 5 features for Gestational Trophoblastic Disease: ['SPP1 (6696)', 'CLDN6 (9074)', 'SFRP2 (6423)', 'EDNRB (1910)', 'LIN28A (79727)']
# Top 5 features for Ovarian Germ Cell Tumor: ['DHRS2 (10202)', 'KRT81 (3887)', 'RPS4Y1 (6192)', 'ACTL8 (81569)', 'CTAG2 (30848)']
# Top 5 features for Fibrosarcoma: ['XAGE1A (653220)', 'NTS (4922)', 'XAGE1B (653067)', 'DPEP3 (64180)', 'LGALS1 (3956)']
# Top 5 features for Adrenocortical Carcinoma: ['CALML3 (810)', 'CEACAM6 (4680)', 'LDHB (3945)', 'GSTP1 (2950)', 'TPM4 (7171)']
# Top 5 features for Prostate Small Cell Carcinoma: ['FGB (2244)', 'SPP1 (6696)', 'ALDH1A1 (216)', 'SLC17A3 (10786)', 'CXCL5 (6374)']
# Top 5 features for Epithelioid Sarcoma: ['MMP1 (4312)', 'CXCL6 (6372)', 'SMR3B (10879)', 'MMP13 (4322)', 'TIE1 (7075)']
# Top 5 features for Poorly Differentiated Thyroid Cancer: ['CALCA (796)', 'SST (6750)', 'TSPAN8 (7103)', 'TPH1 (7166)', 'GCNT3 (9245)']
# Top 5 features for Pancreatic Neuroendocrine Tumor: ['HBG2 (3048)', 'PRG2 (5553)', 'HLA-DRA (3122)', 'FAM178B (51252)', 'AVP (551)']
# Top 5 features for Myelodysplastic Syndromes: ['MGP (4256)', 'VTCN1 (79679)', 'ACTG2 (72)', 'CALB2 (794)', 'AZGP1 (563)']

# %%
df_coef = pd.DataFrame(coef_map)

df_coef = df_coef.transpose()

df_coef.fillna('', inplace=True)

df_coef.reset_index(inplace=True)

df_coef.rename(columns={'index': 'Primary Disease'}, inplace=True)

new_columns = {col: f"#{i+1} Most Weighted RNA" for i, col in enumerate(df_coef.columns[1:])}
df_coef.rename(columns=new_columns, inplace=True)

df_coef
# Out:
#                                     Primary Disease #1 Most Weighted RNA  \
# 0                        Non-Small Cell Lung Cancer      XAGE1A (653220)
# 1                                   Embryonal Tumor       CHRNA9 (55584)
# 2                                          Melanoma         UCHL1 (7345)
# 3   Intraductal Papillary Neoplasm of the Bile Duct          SPP1 (6696)
# 4                      Bladder Urothelial Carcinoma          LCP1 (3936)
# ..                                              ...                  ...
# 70                    Prostate Small Cell Carcinoma           FGB (2244)
# 71                              Epithelioid Sarcoma          MMP1 (4312)
# 72             Poorly Differentiated Thyroid Cancer          CALCA (796)
# 73                  Pancreatic Neuroendocrine Tumor          HBG2 (3048)
# 74                        Myelodysplastic Syndromes           MGP (4256)
#
#    #2 Most Weighted RNA #3 Most Weighted RNA #4 Most Weighted RNA  \
# 0       XAGE1B (653067)      RNF212 (285498)           BST2 (684)
# 1            MGP (4256)    TSTD1 (100131187)        S100A4 (6275)
# 2           MEST (4232)          LCP1 (3936)         S100B (6285)
# 3            BMP4 (652)          PXDN (7837)           CFH (3075)
# 4       RPL39L (116832)       IFITM2 (10581)         HOXA9 (3205)
# ..                  ...                  ...                  ...
# 70          SPP1 (6696)        ALDH1A1 (216)      SLC17A3 (10786)
# 71         CXCL6 (6372)        SMR3B (10879)         MMP13 (4322)
# 72           SST (6750)        TSPAN8 (7103)          TPH1 (7166)
# 73          PRG2 (5553)       HLA-DRA (3122)      FAM178B (51252)
# 74        VTCN1 (79679)           ACTG2 (72)          CALB2 (794)
#
#    #5 Most Weighted RNA
# 0          HOXB2 (3212)
# 1       HENMT1 (113802)
# 2           GJA1 (2697)
# 3            CPE (1363)
# 4           PXDN (7837)
# ..                  ...
# 70         CXCL5 (6374)
# 71          TIE1 (7075)
# 72         GCNT3 (9245)
# 73            AVP (551)
# 74          AZGP1 (563)
#
# [75 rows x 6 columns]
